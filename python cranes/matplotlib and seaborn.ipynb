# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('corporate_employee_data.csv')
df.head()

# %%
df.info()

# %%
df.describe(include='all')
