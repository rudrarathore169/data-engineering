# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('unclean_data.csv',encoding='latin1')

# %%
df.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   movie_title                14 non-null     object
#  1   num_critic_for_reviews     14 non-null     int64
#  2   duration                   11 non-null     float64
#  3   DIRECTOR_facebook_likes    12 non-null     object
#  4   actor_3_facebook_likes     14 non-null     int64
#  5   ACTOR_1_facebook_likes     14 non-null     int64
#  6   gross                      14 non-null     int64
#  7   num_voted_users            13 non-null     float64
#  8   Cast_Total_facebook_likes  12 non-null     float64
#  9   facenumber_in_poster       9 non-null      float64
#  10  num_user_for_reviews       14 non-null     int64
#  11  budget                     14 non-null     int64
#  12  title_year                 14 non-null     int64
# ...

# %%
df.describe()
# Out:
#        num_critic_for_reviews    duration  actor_3_facebook_likes  \
# count               14.000000   11.000000               14.000000
# mean               506.142857  150.727273             5866.142857
# std                169.069789   21.679903             8289.592695
# min                302.000000  106.000000              161.000000
# 25%                379.250000  141.000000              611.250000
# 50%                448.000000  151.000000             1000.000000
# 75%                635.000000  162.500000             8500.000000
# max                813.000000  183.000000            23000.000000
#
#        ACTOR_1_facebook_likes         gross  num_voted_users  \
# count               14.000000  1.400000e+01     1.300000e+01
# mean             18206.428571  3.335836e+08     4.621578e+05
# std              13905.214361  1.720674e+08     2.687059e+05
# min                451.000000  7.305868e+07     2.122040e+05
# 25%               3500.000000  2.002574e+08     2.948100e+05
# ...

# %%
df.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     3
# DIRECTOR_facebook_likes      2
# actor_3_facebook_likes       0
# ACTOR_1_facebook_likes       0
# gross                        0
# num_voted_users              1
# Cast_Total_facebook_likes    2
# facenumber_in_poster         5
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# ACTOR_2_facebook_likes       1
# imdb_score                   0
# title_year.1                 7
# dtype: int64

# %%
df.isnull().any()
# Out:
# movie_title                  False
# num_critic_for_reviews       False
# duration                      True
# DIRECTOR_facebook_likes       True
# actor_3_facebook_likes       False
# ACTOR_1_facebook_likes       False
# gross                        False
# num_voted_users               True
# Cast_Total_facebook_likes     True
# facenumber_in_poster          True
# num_user_for_reviews         False
# budget                       False
# title_year                   False
# ACTOR_2_facebook_likes        True
# imdb_score                   False
# title_year.1                  True
# dtype: bool

# %%
df.isnull().sum().sum()
# Out:
# np.int64(21)

# %%
df.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
df["movie_title"]=(df["movie_title"].str.replace("?ÿ","",regex=False).str.strip())

# %%
df.head()
# Out:
#                                 movie_title  num_critic_for_reviews  duration  \
# 0                                    Avatar                     723     178.0
# 1  Pirates of the Caribbean: At World's End                     302       NaN
# 2                                   Spectre                     602     148.0
# 3                     The Dark Knight Rises                     813       NaN
# 4                               John Carter                     462     132.0
#
#   DIRECTOR_facebook_likes  actor_3_facebook_likes  ACTOR_1_facebook_likes  \
# 0                      10                     855                    1000
# 1                     563                    1000                   40000
# 2                      20                     161                   11000
# 3                   22000                   23000                   27000
# 4                   "475"                     530                     640
#
# ...

# %%
df['duration']=df['duration'].fillna(df['duration'].mean())

# %%
df.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     0
# DIRECTOR_facebook_likes      2
# actor_3_facebook_likes       0
# ACTOR_1_facebook_likes       0
# gross                        0
# num_voted_users              1
# Cast_Total_facebook_likes    2
# facenumber_in_poster         5
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# ACTOR_2_facebook_likes       1
# imdb_score                   0
# title_year.1                 7
# dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# dtype: bool

# %%
df.duplicated('movie_title')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# dtype: bool

# %%
df.head(10)
# Out:
#                                 movie_title  num_critic_for_reviews  \
# 0                                    Avatar                     723
# 1  Pirates of the Caribbean: At World's End                     302
# 2                                   Spectre                     602
# 3                     The Dark Knight Rises                     813
# 4                               John Carter                     462
# 5                              Spider-Man 3                     392
# 6                                   Tangled                     324
# 7                   Avengers: Age of Ultron                     635
# 8                   Avengers: Age of Ultron                     635
# 9    Harry Potter and the Half-Blood Prince                     375
#
#      duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0  178.000000                      10                     855
# 1  150.727273                     563                    1000
# ...

# %%
df.shape
# Out:
# (14, 16)

# %%
df = df.drop_duplicates('movie_title')

# %%
df.shape
# Out:
# (13, 16)

# %%
df.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     0
# DIRECTOR_facebook_likes      2
# actor_3_facebook_likes       0
# ACTOR_1_facebook_likes       0
# gross                        0
# num_voted_users              1
# Cast_Total_facebook_likes    2
# facenumber_in_poster         5
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# ACTOR_2_facebook_likes       1
# imdb_score                   0
# title_year.1                 7
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, 0 to 13
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   movie_title                13 non-null     object
#  1   num_critic_for_reviews     13 non-null     int64
#  2   duration                   13 non-null     float64
#  3   DIRECTOR_facebook_likes    11 non-null     object
#  4   actor_3_facebook_likes     13 non-null     int64
#  5   ACTOR_1_facebook_likes     13 non-null     int64
#  6   gross                      13 non-null     int64
#  7   num_voted_users            12 non-null     float64
#  8   Cast_Total_facebook_likes  11 non-null     float64
#  9   facenumber_in_poster       8 non-null      float64
#  10  num_user_for_reviews       13 non-null     int64
#  11  budget                     13 non-null     int64
#  12  title_year                 13 non-null     int64
# ...

# %%
df.drop('title_year.1',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# movie_title                   0
# num_critic_for_reviews        0
# duration                      0
# DIRECTOR_facebook_likes       2
# actor_3_facebook_likes        0
# ACTOR_1_facebook_likes        0
# gross                         0
# num_voted_users               1
# Cast_Total_facebook_likes     2
# facenumber_in_poster         13
# num_user_for_reviews          0
# budget                        0
# title_year                    0
# ACTOR_2_facebook_likes        1
# imdb_score                    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, 0 to 13
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   movie_title                13 non-null     object
#  1   num_critic_for_reviews     13 non-null     int64
#  2   duration                   13 non-null     float64
#  3   DIRECTOR_facebook_likes    11 non-null     object
#  4   actor_3_facebook_likes     13 non-null     int64
#  5   ACTOR_1_facebook_likes     13 non-null     int64
#  6   gross                      13 non-null     int64
#  7   num_voted_users            12 non-null     float64
#  8   Cast_Total_facebook_likes  11 non-null     float64
#  9   facenumber_in_poster       0 non-null      object
#  10  num_user_for_reviews       13 non-null     int64
#  11  budget                     13 non-null     int64
#  12  title_year                 13 non-null     int64
# ...

# %%
df["DIRECTOR_facebook_likes"]=pd.to_numeric(df["DIRECTOR_facebook_likes"],errors='coerce')

# %%
median_cols=[
    "DIRECTOR_facebook_likes",
    "num_voted_users",
    "Cast_Total_facebook_likes",
    "ACTOR_2_facebook_likes"
]
# for col in median_cols:
#     df[col].fillna(df[col].median(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, 0 to 13
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   movie_title                13 non-null     object
#  1   num_critic_for_reviews     13 non-null     int64
#  2   duration                   13 non-null     float64
#  3   DIRECTOR_facebook_likes    10 non-null     float64
#  4   actor_3_facebook_likes     13 non-null     int64
#  5   ACTOR_1_facebook_likes     13 non-null     int64
#  6   gross                      13 non-null     int64
#  7   num_voted_users            12 non-null     float64
#  8   Cast_Total_facebook_likes  11 non-null     float64
#  9   facenumber_in_poster       0 non-null      object
#  10  num_user_for_reviews       13 non-null     int64
#  11  budget                     13 non-null     int64
#  12  title_year                 13 non-null     int64
# ...

# %%
df
