# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
date = [datetime(2020,1,5),
        datetime(2020,1,10),
        datetime(2020,1,15),
        datetime(2020,1,20),
        datetime(2020,1,25)
       ]

# %%
date
# Out:
# [datetime.datetime(2020, 1, 5, 0, 0),
#  datetime.datetime(2020, 1, 10, 0, 0),
#  datetime.datetime(2020, 1, 15, 0, 0),
#  datetime.datetime(2020, 1, 20, 0, 0),
#  datetime.datetime(2020, 1, 25, 0, 0)]

# %%
ts = pd.Series(np.random.rand(5),index = date)
ts
# Out:
# 2020-01-05    0.134076
# 2020-01-10    0.598716
# 2020-01-15    0.676676
# 2020-01-20    0.022596
# 2020-01-25    0.762660
# dtype: float64

# %%
ts.index
# Out:
# DatetimeIndex(['2020-01-05', '2020-01-10', '2020-01-15', '2020-01-20',
#                '2020-01-25'],
#               dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime("01/01/2020")
# Out:
# Timestamp('2020-01-01 00:00:00')

# %%
dates = pd.to_datetime(
    [
        datetime(2020,7,5),
        "6th of july, 2020",
        "2020-july-7",
        "20200708"
    ]
)
dates
# Out:
# DatetimeIndex(['2020-07-05', '2020-07-06', '2020-07-07', '2020-07-08'], dtype='datetime64[ns]', freq=None)

# %%
dates.to_period("D")
# Out:
# PeriodIndex(['2020-07-05', '2020-07-06', '2020-07-07', '2020-07-08'], dtype='period[D]')

# %%
dates-dates[0]
# Out:
# TimedeltaIndex(['0 days', '1 days', '2 days', '3 days'], dtype='timedelta64[ns]', freq=None)

# %%
pd.date_range("2020-08-15","2020-09-01")
# Out:
# DatetimeIndex(['2020-08-15', '2020-08-16', '2020-08-17', '2020-08-18',
#                '2020-08-19', '2020-08-20', '2020-08-21', '2020-08-22',
#                '2020-08-23', '2020-08-24', '2020-08-25', '2020-08-26',
#                '2020-08-27', '2020-08-28', '2020-08-29', '2020-08-30',
#                '2020-08-31', '2020-09-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2020-07-15',periods =10)
# Out:
# DatetimeIndex(['2020-07-15', '2020-07-16', '2020-07-17', '2020-07-18',
#                '2020-07-19', '2020-07-20', '2020-07-21', '2020-07-22',
#                '2020-07-23', '2020-07-24'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range("2020-07-15",periods =10,freq = "h")
# Out:
# DatetimeIndex(['2020-07-15 00:00:00', '2020-07-15 01:00:00',
#                '2020-07-15 02:00:00', '2020-07-15 03:00:00',
#                '2020-07-15 04:00:00', '2020-07-15 05:00:00',
#                '2020-07-15 06:00:00', '2020-07-15 07:00:00',
#                '2020-07-15 08:00:00', '2020-07-15 09:00:00'],
#               dtype='datetime64[ns]', freq='h')

# %%
pd.period_range("2020-10",periods=10,freq="M")
# Out:
# PeriodIndex(['2020-10', '2020-11', '2020-12', '2021-01', '2021-02', '2021-03',
#              '2021-04', '2021-05', '2021-06', '2021-07'],
#             dtype='period[M]')

# %%
pd.timedelta_range(0,periods=8,freq = "h")
# Out:
# TimedeltaIndex(['0 days 00:00:00', '0 days 01:00:00', '0 days 02:00:00',
#                 '0 days 03:00:00', '0 days 04:00:00', '0 days 05:00:00',
#                 '0 days 06:00:00', '0 days 07:00:00'],
#                dtype='timedelta64[ns]', freq='h')

# %%
stamps = ts.index[1]

# %%
stamps
# Out:
# Timestamp('2020-01-10 00:00:00')

# %%
ts["25.1.2020"]
# Out:
# np.float64(0.7626601649007327)

# %%
ts["20200125"]
# Out:
# np.float64(0.7626601649007327)

# %%
long_ts = pd.Series(np.random.rand(1000),index=pd.date_range("1/1/2020",periods=1000))
long_ts.head()
# Out:
# 2020-01-01    0.691236
# 2020-01-02    0.045316
# 2020-01-03    0.682059
# 2020-01-04    0.701325
# 2020-01-05    0.405161
# Freq: D, dtype: float64

# %%
long_ts["2020-10"].head(15)
# Out:
# 2020-10-01    0.019430
# 2020-10-02    0.501408
# 2020-10-03    0.000186
# 2020-10-04    0.271095
# 2020-10-05    0.323141
# 2020-10-06    0.111935
# 2020-10-07    0.906127
# 2020-10-08    0.025058
# 2020-10-09    0.135958
# 2020-10-10    0.907692
# 2020-10-11    0.473117
# 2020-10-12    0.136122
# 2020-10-13    0.447258
# 2020-10-14    0.549079
# 2020-10-15    0.841750
# Freq: D, dtype: float64

# %%
long_ts[datetime(2022,9,20):]
# Out:
# 2022-09-20    0.378218
# 2022-09-21    0.324138
# 2022-09-22    0.545828
# 2022-09-23    0.456414
# 2022-09-24    0.610676
# 2022-09-25    0.845699
# 2022-09-26    0.400222
# Freq: D, dtype: float64

# %%
ts
# Out:
# 2020-01-05    0.134076
# 2020-01-10    0.598716
# 2020-01-15    0.676676
# 2020-01-20    0.022596
# 2020-01-25    0.762660
# dtype: float64

# %%
ts.truncate(after="1/15/2020")
# Out:
# 2020-01-05    0.134076
# 2020-01-10    0.598716
# 2020-01-15    0.676676
# dtype: float64

# %%
date = pd.date_range("1/1/2020",periods = 100,freq = "W-SUN")

# %%
date
# Out:
# DatetimeIndex(['2020-01-05', '2020-01-12', '2020-01-19', '2020-01-26',
#                '2020-02-02', '2020-02-09', '2020-02-16', '2020-02-23',
#                '2020-03-01', '2020-03-08', '2020-03-15', '2020-03-22',
#                '2020-03-29', '2020-04-05', '2020-04-12', '2020-04-19',
#                '2020-04-26', '2020-05-03', '2020-05-10', '2020-05-17',
#                '2020-05-24', '2020-05-31', '2020-06-07', '2020-06-14',
#                '2020-06-21', '2020-06-28', '2020-07-05', '2020-07-12',
#                '2020-07-19', '2020-07-26', '2020-08-02', '2020-08-09',
#                '2020-08-16', '2020-08-23', '2020-08-30', '2020-09-06',
#                '2020-09-13', '2020-09-20', '2020-09-27', '2020-10-04',
#                '2020-10-11', '2020-10-18', '2020-10-25', '2020-11-01',
#                '2020-11-08', '2020-11-15', '2020-11-22', '2020-11-29',
#                '2020-12-06', '2020-12-13', '2020-12-20', '2020-12-27',
# ...

# %%
long_df = pd.DataFrame(np.random.randn(100,4),index = date,columns = list("ABCD"))
long_df
# Out:
#                    A         B         C         D
# 2020-01-05 -0.051913  0.162991 -1.346588  0.799165
# 2020-01-12  0.907934 -0.190456 -1.154761  0.393183
# 2020-01-19  1.005569 -0.755776  0.003217 -0.606787
# 2020-01-26 -0.475133 -2.380676  0.116399 -0.018358
# 2020-02-02  0.782214  0.350522 -0.708365 -0.138207
# ...              ...       ...       ...       ...
# 2021-10-31 -0.446058 -0.915791 -0.453943  1.957510
# 2021-11-07 -0.811803 -0.489396  0.533828  1.616975
# 2021-11-14  1.532031 -0.279045 -0.827156  0.188145
# 2021-11-21 -0.563168  0.345614  0.241351  1.536613
# 2021-11-28  1.431240  2.040109 -0.118766 -0.430856
#
# [100 rows x 4 columns]

# %%
long_df["2021-11-31"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
# --> 167 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
# --> 196 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7088 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# ...

# %%
date = pd.DatetimeIndex(
    [
        "1/1/2020","1/2/2020","1/2/2020",
        "1/2/2020","1/3/2020"
    ]
)

ts1 = pd.Series(np.arange(5),index=date)
ts1
# Out:
# 2020-01-01    0
# 2020-01-02    1
# 2020-01-02    2
# 2020-01-02    3
# 2020-01-03    4
# dtype: int64

# %%
ts1.index.is_unique
# Out:
# False

# %%
ts
# Out:
# 2020-01-05    0.134076
# 2020-01-10    0.598716
# 2020-01-15    0.676676
# 2020-01-20    0.022596
# 2020-01-25    0.762660
# dtype: float64

# %%
group = ts1.groupby(level=0)

# %%
group.count()
# Out:
# 2020-01-01    1
# 2020-01-02    3
# 2020-01-03    1
# dtype: int64

# %%
group.mean(),std(),var()# for read only
