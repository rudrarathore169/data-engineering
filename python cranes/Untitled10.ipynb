# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('50_Startups.csv')
df.head()
X = df.drop(columns=['Profit'])
y = df.iloc[:,-1:]
X = pd.get_dummies(X,columns=['State'],drop_first=True,dtype=int)

from sklearn.preprocessing import StandardScaler

# Create scaler
scaler = StandardScaler()

# Scale X
X_scaled = scaler.fit_transform(X)

# Convert back to DataFrame (optional but recommended)
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

print(X_scaled.head())
# Out:
#    R&D Spend  Administration  Marketing Spend  State_Florida  State_New York
# 0   2.016411        0.560753         2.153943      -0.685994        1.393261
# 1   1.955860        1.082807         1.923600      -0.685994       -0.717741
# 2   1.754364       -0.728257         1.626528       1.457738       -0.717741
# 3   1.554784       -0.096365         1.422210      -0.685994        1.393261
# 4   1.504937       -1.079919         1.281528       1.457738       -0.717741

# %%
X
# Out:
#     R&D Spend  Administration  Marketing Spend  State_Florida  State_New York
# 0   165349.20       136897.80        471784.10              0               1
# 1   162597.70       151377.59        443898.53              0               0
# 2   153441.51       101145.55        407934.54              1               0
# 3   144372.41       118671.85        383199.62              0               1
# 4   142107.34        91391.77        366168.42              1               0
# 5   131876.90        99814.71        362861.36              0               1
# 6   134615.46       147198.87        127716.82              0               0
# 7   130298.13       145530.06        323876.68              1               0
# 8   120542.52       148718.95        311613.29              0               1
# 9   123334.88       108679.17        304981.62              0               0
# 10  101913.08       110594.11        229160.95              1               0
# ...

# %%
y
# Out:
#        Profit
# 0   192261.83
# 1   191792.06
# 2   191050.39
# 3   182901.99
# 4   166187.94
# 5   156991.12
# 6   156122.51
# 7   155752.60
# 8   152211.77
# 9   149759.96
# 10  146121.95
# 11  144259.40
# 12  141585.52
# 13  134307.35
# 14  132602.65
# 15  129917.04
# 16  126992.93
# 17  125370.37
# 18  124266.90
# 19  122776.86
# 20  118474.03
# 21  111313.02
# 22  110352.25
# 23  108733.99
# 24  108552.04
# 25  107404.34
# 26  105733.54
# 27  105008.31
# 28  103282.38
# 29  101004.64
# 30   99937.59
# 31   97483.56
# 32   97427.84
# 33   96778.92
# 34   96712.80
# 35   96479.51
# 36   90708.19
# 37   89949.14
# 38   81229.06
# 39   81005.76
# 40   78239.91
# 41   77798.83
# 42   71498.49
# 43   69758.98
# 44   65200.33
# 45   64926.08
# 46   49490.75
# 47   42559.73
# 48   35673.41
# 49   14681.40

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("mse",mean_squared_error(y_test,y_pred))
print("rmse",rmse)
# Out:
# mse 82010363.04430112
# rmse 9055.957323458471

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# [54028.03959365]
# [[ 8.05630064e-01 -6.87878823e-02  2.98554429e-02  9.38793006e+02
#    6.98775997e+00]]

# %%
import statsmodels.api as sm
x_train=sm.add_constant(x_train)
x_test=sm.add_constant(x_test)
model=sm.OLS(y_train,x_train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.947
# Method:                 Least Squares   F-statistic:                     140.1
# Date:                Thu, 06 Aug 2026   Prob (F-statistic):           1.13e-21
# Time:                        10:58:57   Log-Likelihood:                -420.63
# No. Observations:                  40   AIC:                             853.3
# Df Residuals:                      34   BIC:                             863.4
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
x_train = x_train.iloc[:,:-1]
model=sm.OLS(y_train,x_train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     180.2
# Date:                Thu, 06 Aug 2026   Prob (F-statistic):           7.85e-23
# Time:                        10:59:06   Log-Likelihood:                -420.63
# No. Observations:                  40   AIC:                             851.3
# Df Residuals:                      35   BIC:                             859.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
x_train = x_train.iloc[:,:-1]
model=sm.OLS(y_train,x_train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     246.6
# Date:                Thu, 06 Aug 2026   Prob (F-statistic):           4.76e-24
# Time:                        10:59:29   Log-Likelihood:                -420.68
# No. Observations:                  40   AIC:                             849.4
# Df Residuals:                      36   BIC:                             856.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
x_train = x_train.iloc[:,[0,1,3]]
model=sm.OLS(y_train,x_train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.952
# Model:                            OLS   Adj. R-squared:                  0.949
# Method:                 Least Squares   F-statistic:                     366.0
# Date:                Thu, 06 Aug 2026   Prob (F-statistic):           4.19e-25
# Time:                        10:59:58   Log-Likelihood:                -421.40
# No. Observations:                  40   AIC:                             848.8
# Df Residuals:                      37   BIC:                             853.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import LinearRegression
x_train=sm.add_constant(x_train)
x_test=sm.add_constant(x_test)
regressor=LinearRegression()
sfs = SequentialFeatureSelector(regressor,n_features_to_select=2,direction='forward')
sfs.fit(x_train,y_train)
print(sfs.get_support())
print(x_train.columns[sfs.get_support()])
# Out:
# [False  True  True False False False]
# Index(['R&D Spend', 'Administration'], dtype='object')

# %%
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import LinearRegression
x_train=sm.add_constant(x_train)
x_test=sm.add_constant(x_test)
regressor=LinearRegression()
sfs = SequentialFeatureSelector(regressor,n_features_to_select='auto',tol=0.00179,direction='forward')
sfs.fit(x_train,y_train)
print(sfs.get_support())
print(x_train.columns[sfs.get_support()])
# Out:
# [False  True  True False False False]
# Index(['R&D Spend', 'Administration'], dtype='object')

# %%
#recursive feature elimination

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
rfe = RFE(estimator=regressor,n_features_to_select=2)
rfe.fit(x_train,y_train)

selected_features=x_train.columns[rfe.support_]
print(selected_features)
# Out:
# Index(['R&D Spend', 'Marketing Spend'], dtype='object')

# %%
from sklearn.linear_model import Lasso,Ridge
ls = Lasso(alpha=100)
ls.fit(x_train,y_train)
rdg = Ridge()
rdg.fit(x_train,y_train)
print(rdg.coef_)
print(ls.coef_)
# Out:
# [34753.1345367  -1423.16670463  5076.01541871   341.06791068
#     68.75714761]
# [36503.8847558  -1786.80645111  3619.50205216   349.24437337
#     -0.        ]

# %%
from sklearn.linear_model import LassoCV
lasso_cv = LassoCV(alphas=[0.1,1,10,100,1000],cv = 5,max_iter=100000)
lasso_cv.fit(x_train,y_train)
print(lasso_cv.alpha_)
# Out:
# 1000.0
# C:\Users\Rudra Pratap Singh\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:1714: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.linear_model import RidgeCV
rdg_cv = RidgeCV(alphas=[0.1,1,10,100,1000],cv = 5)
rdg_cv.fit(x_train,y_train)
print(rdg_cv.alpha_)
# Out:
# 0.1
